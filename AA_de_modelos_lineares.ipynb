# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import seaborn as sns

# %%
# Modifiquei o separador na mão pra conseguir usar o dataset

df = pd.read_csv("./drive/MyDrive/DataSet_AA.csv", sep=';')

# %% [markdown]
# ## Analise inicial do DataFrame

# %%
# Vizualizando o começo do df

df.head()
# Out:
#    Area  Garage  Lareira  Banheiros  Marmore Branco  Marmore Preto  \
# 0   164       2        0          2               0              1
# 1    84       2        0          4               0              0
# 2   190       2        4          4               1              0
# 3    75       2        4          4               0              0
# 4   148       1        4          2               1              0
#
#    Marmore Indiano  Andares  Cidade  Solar  Electrica  Fibra  Porta de vidro  \
# 0                0        0       3      1          1      1               1
# 1                1        1       2      0          0      0               1
# 2                0        0       2      0          0      1               0
# 3                1        1       1      1          1      1               1
# 4                0        1       2      1          0      0               1
#
#    Piscina  Jardim  Preços
# 0        0       0   43800
# 1        1       1   37550
# ...

# %%
# Entendendo quantas linhas e colunas o df tem

df.shape
# Out:
# (500000, 16)

# %%
# Conhecendo quais são as colunas do df

df.columns
# Out:
# Index(['Area', 'Garage', 'Lareira', 'Banheiros', 'Marmore Branco',
#        'Marmore Preto', 'Marmore Indiano', 'Andares', 'Cidade', 'Solar',
#        'Electrica', 'Fibra', 'Porta de vidro', 'Piscina', 'Jardim', 'Preços'],
#       dtype='object')

# %%
# Vendo quais tipos de dados se tem em cada coluna

df.dtypes
# Out:
# Area               int64
# Garage             int64
# Lareira            int64
# Banheiros          int64
# Marmore Branco     int64
# Marmore Preto      int64
# Marmore Indiano    int64
# Andares            int64
# Cidade             int64
# Solar              int64
# Electrica          int64
# Fibra              int64
# Porta de vidro     int64
# Piscina            int64
# Jardim             int64
# Preços             int64
# dtype: object

# %%
# Conhecendo os valores máximos de cada coluna

df.max()
# Out:
# Area                 249
# Garage                 3
# Lareira                4
# Banheiros              5
# Marmore Branco         1
# Marmore Preto          1
# Marmore Indiano        1
# Andares                1
# Cidade                 3
# Solar                  1
# Electrica              1
# Fibra                  1
# Porta de vidro         1
# Piscina                1
# Jardim                 1
# Preços             77975
# dtype: int64

# %%
# Conhecendo os valores mínimos de cada coluna

df.min()
# Out:
# Area                  1
# Garage                1
# Lareira               0
# Banheiros             1
# Marmore Branco        0
# Marmore Preto         0
# Marmore Indiano       0
# Andares               0
# Cidade                1
# Solar                 0
# Electrica             0
# Fibra                 0
# Porta de vidro        0
# Piscina               0
# Jardim                0
# Preços             7725
# dtype: int64

# %%
# Um resumo estatístico do df

df.describe()
# Out:
#                 Area         Garage        Lareira      Banheiros  \
# count  500000.000000  500000.000000  500000.000000  500000.000000
# mean      124.929554       2.001290       2.003398       2.998074
# std        71.795363       0.817005       1.414021       1.414227
# min         1.000000       1.000000       0.000000       1.000000
# 25%        63.000000       1.000000       1.000000       2.000000
# 50%       125.000000       2.000000       2.000000       3.000000
# 75%       187.000000       3.000000       3.000000       4.000000
# max       249.000000       3.000000       4.000000       5.000000
#
#        Marmore Branco  Marmore Preto  Marmore Indiano        Andares  \
# count   500000.000000  500000.000000    500000.000000  500000.000000
# mean         0.332992       0.332690         0.334318       0.499386
# std          0.471284       0.471177         0.471752       0.500000
# min          0.000000       0.000000         0.000000       0.000000
# ...

# %%
# Verificando se há valores nulos no df

df.isnull().sum()
# Out:
# Area               0
# Garage             0
# Lareira            0
# Banheiros          0
# Marmore Branco     0
# Marmore Preto      0
# Marmore Indiano    0
# Andares            0
# Cidade             0
# Solar              0
# Electrica          0
# Fibra              0
# Porta de vidro     0
# Piscina            0
# Jardim             0
# Preços             0
# dtype: int64

# %%
df.sort_values(by=['Area','Preços'], ascending=[True,False])
# Out:
#         Area  Garage  Lareira  Banheiros  Marmore Branco  Marmore Preto  \
# 364058     1       3        3          4               1              0
# 464088     1       2        4          5               1              0
# 142000     1       3        2          3               1              0
# 410089     1       3        0          5               1              0
# 294147     1       2        3          3               1              0
# ...      ...     ...      ...        ...             ...            ...
# 431466   249       2        0          2               0              0
# 179708   249       2        0          1               0              0
# 473224   249       1        0          2               0              0
# 185339   249       1        1          1               0              0
# 494518   249       1        1          2               0              0
#
#         Marmore Indiano  Andares  Cidade  Solar  Electrica  Fibra  \
# ...

# %%
data = df
Valores = np.arange(0, data['Preços'].max()+1, 10000)
data['Valores'] = pd.cut(data['Preços'], Valores)

# %%
select_data = df.columns[0:20]

# %%
select_columns = ['Area', 'Garage', 'Lareira', 'Banheiros', 'Marmore Branco',
       'Marmore Preto', 'Marmore Indiano', 'Andares', 'Cidade', 'Solar',
       'Electrica', 'Fibra', 'Porta de vidro', 'Piscina', 'Jardim', 'Preços','Valores']
select_data = data[select_columns]

# %%
select_data
# Out:
#         Area  Garage  Lareira  Banheiros  Marmore Branco  Marmore Preto  \
# 0        164       2        0          2               0              1
# 1         84       2        0          4               0              0
# 2        190       2        4          4               1              0
# 3         75       2        4          4               0              0
# 4        148       1        4          2               1              0
# ...      ...     ...      ...        ...             ...            ...
# 499995   128       3        4          2               1              0
# 499996    30       2        4          5               0              0
# 499997   174       3        3          2               0              1
# 499998   121       1        4          5               0              1
# 499999    46       2        4          4               1              0
#
#         Marmore Indiano  Andares  Cidade  Solar  Electrica  Fibra  \
# ...

# %%
select_data.describe().round(1)
# Out:
#            Area    Garage   Lareira  Banheiros  Marmore Branco  Marmore Preto  \
# count  500000.0  500000.0  500000.0   500000.0        500000.0       500000.0
# mean      124.9       2.0       2.0        3.0             0.3            0.3
# std        71.8       0.8       1.4        1.4             0.5            0.5
# min         1.0       1.0       0.0        1.0             0.0            0.0
# 25%        63.0       1.0       1.0        2.0             0.0            0.0
# 50%       125.0       2.0       2.0        3.0             0.0            0.0
# 75%       187.0       3.0       3.0        4.0             1.0            1.0
# max       249.0       3.0       4.0        5.0             1.0            1.0
#
#        Marmore Indiano   Andares    Cidade     Solar  Electrica     Fibra  \
# count         500000.0  500000.0  500000.0  500000.0   500000.0  500000.0
# mean               0.3       0.5       2.0       0.5        0.5       0.5
# ...

# %% [markdown]
# # Statsmodels
#
# Criando modelo com Statsmodels

# %%
import statsmodels.api as sm

# %%
y = 'Preços'
modelo = sm.OLS(df[y], df.drop([y], axis=1))
res = modelo.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Preços   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 3.456e+31
# Date:                Mon, 22 May 2023   Prob (F-statistic):               0.00
# Time:                        18:34:50   Log-Likelihood:             1.0124e+07
# No. Observations:              500000   AIC:                        -2.025e+07
# Df Residuals:                  499985   BIC:                        -2.025e+07
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Area               25.0000   7.67e-15   3.26e+15      0.000      25.000      25.000
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = df.drop([y], axis=1)
scaler = StandardScaler()
normalized_X = scaler.fit_transform(X)
normalized_X = pd.DataFrame(normalized_X, columns=X.columns)
normalized_X['intercept'] = 1

modelo = sm.OLS(df[y], normalized_X)
res = modelo.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Preços   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.914e+34
# Date:                Mon, 22 May 2023   Prob (F-statistic):               0.00
# Time:                        18:35:07   Log-Likelihood:             1.1703e+07
# No. Observations:              500000   AIC:                        -2.341e+07
# Df Residuals:                  499985   BIC:                        -2.341e+07
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Area             1794.8823   2.34e-14   7.67e+16      0.000    1794.882    1794.882
# ...

# %% [markdown]
# # Scikit-learn
#
# Criando o modelo com "sklearn"

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

Xtrain, Xval, ytrain, yval = train_test_split(X, data[y], test_size=0.3, random_state=0)
print(Xtrain.shape, Xval.shape, ytrain.shape, yval.shape)

modelo = LinearRegression()
modelo.fit(Xtrain, ytrain)

p = modelo.predict(Xval)
# Out:
# (350000, 15) (150000, 15) (350000,) (150000,)

# %%
from  sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(yval, p))
# Out:
# 1.533354492735774e-10

# %%
modelo.coef_
# Out:
# array([ 2.50000000e+01,  1.50000000e+03,  7.50000000e+02,  1.25000000e+03,
#         7.66666667e+03, -1.33333333e+03, -6.33333333e+03,  1.50000000e+04,
#         3.50000000e+03,  2.50000000e+02,  1.25000000e+03,  1.17500000e+04,
#         4.45000000e+03,  5.52802248e-12, -6.02540240e-12])

# %% [markdown]
# # Scikit-learn standardizado

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


Xtrain, Xval, ytrain, yval = train_test_split(X, data[y], test_size=0.3, random_state=0)
print(Xtrain.shape, Xval.shape, ytrain.shape, yval.shape)

scaler = StandardScaler()
Xtrain_scaled = scaler.fit_transform(Xtrain)
Xval_scaled = scaler.transform(Xval)

modelo = LinearRegression(fit_intercept=False)
modelo.fit(Xtrain_scaled, ytrain)

p = modelo.predict(Xtrain_scaled)
# Out:
# (350000, 15) (150000, 15) (350000,) (150000,)

# %%
modelo.coef_
# Out:
# array([ 1.79433384e+03,  1.22531369e+03,  1.06072637e+03,  1.76896099e+03,
#         3.61487422e+03, -6.25982399e+02, -2.98531321e+03,  7.49996963e+03,
#         2.85680169e+03,  1.24999763e+02,  6.24999915e+02,  5.87498791e+03,
#         2.22499984e+03, -2.35900188e-12, -3.06954462e-12])
